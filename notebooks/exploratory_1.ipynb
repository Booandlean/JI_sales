# %% [markdown]
# # Exploratory 1

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_CM_raw = pd.read_csv('amz_reports/CMJI.csv')


df_CM_raw.sample(10)
# Out:
#        Start Date      End Date Portfolio name Currency  \
# 188  Jan 07, 2021  Jan 09, 2021    Not grouped      USD
# 29   Dec 25, 2020  Jan 14, 2021    Not grouped      USD
# 236  Jan 13, 2021  Jan 13, 2021    Not grouped      USD
# 58   Jan 04, 2021  Jan 04, 2021    Not grouped      USD
# 96   Dec 26, 2020  Jan 06, 2021    Not grouped      USD
# 214  Dec 30, 2020  Jan 06, 2021    Not grouped      USD
# 63   Jan 04, 2021  Jan 04, 2021    Not grouped      USD
# 196  Jan 02, 2021  Jan 02, 2021    Not grouped      USD
# 79   Dec 20, 2020  Dec 20, 2020    Not grouped      USD
# 207  Dec 22, 2020  Dec 22, 2020    Not grouped      USD
#
#                              Campaign Name   Ad Group Name  \
# 188  Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# 29   Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# 236  Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# 58   Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# ...

# %%
len(df_CM_raw['Currency'])
# Out:
# 248

# %%
df_PM_raw = pd.read_csv('amz_reports/PMJI.csv')


df_PM_raw.sample(10)
