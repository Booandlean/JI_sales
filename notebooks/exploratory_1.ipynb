# %% [markdown]
# # Exploratory 1

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_CM_raw = pd.read_csv('../amz_reports/JICM_.csv')


df_CM_raw.sample(10)
# Out:
#      Start Date    End Date Portfolio name Currency  \
# 214  2020-12-30  2021-01-06    Not grouped      USD
# 27   2020-12-27  2020-12-27    Not grouped      USD
# 37   2020-12-31  2020-12-31    Not grouped      USD
# 68   2021-01-05  2021-01-05    Not grouped      USD
# 237  2020-12-21  2020-12-28    Not grouped      USD
# 122  2020-12-20  2020-12-20    Not grouped      USD
# 54   2021-01-14  2021-01-14    Not grouped      USD
# 160  2020-12-21  2020-12-21    Not grouped      USD
# 150  2021-01-03  2021-01-03    Not grouped      USD
# 212  2021-01-13  2021-01-13    Not grouped      USD
#
#                              Campaign Name   Ad Group Name  \
# 214  Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# 27   Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# 37   Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# 68   Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# 237  Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# ...

# %%
df_CM_raw.columns = df_CM_raw.columns.str.replace(' ', '_')
df_CM_raw.head()
# Out:
#    Start_Date    End_Date Portfolio_name Currency  \
# 0  2021-01-07  2021-01-07    Not grouped      USD
# 1  2021-01-12  2021-01-12    Not grouped      USD
# 2  2021-01-12  2021-01-12    Not grouped      USD
# 3  2021-01-12  2021-01-12    Not grouped      USD
# 4  2020-12-28  2020-12-28    Not grouped      USD
#
#                            Campaign_Name   Ad_Group_Name  \
# 0  Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# 1  Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# 2  Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# 3  Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# 4  Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
#
#               Targeting Match_Type  \
# 0  kitchen knife sheath      BROAD
# 1  kitchen knife sheath      BROAD
# 2  kitchen knife sheath      BROAD
# 3  kitchen knife sheath      BROAD
# 4  kitchen knife sheath      BROAD
#
#                              Customer_Search_Term  Impressions  ...  \
# ...

# %%
df_CM_raw.set_index('Start_Date')
# Out:
#               End_Date Portfolio_name Currency  \
# Start_Date
# 2021-01-07  2021-01-07    Not grouped      USD
# 2021-01-12  2021-01-12    Not grouped      USD
# 2021-01-12  2021-01-12    Not grouped      USD
# 2021-01-12  2021-01-12    Not grouped      USD
# 2020-12-28  2020-12-28    Not grouped      USD
# ...                ...            ...      ...
# 2020-12-22  2021-01-10    Not grouped      USD
# 2020-12-24  2021-01-10    Not grouped      USD
# 2021-01-01  2021-01-01    Not grouped      USD
# 2020-12-24  2020-12-24    Not grouped      USD
# 2020-12-23  2020-12-23    Not grouped      USD
#
#                                     Campaign_Name   Ad_Group_Name  \
# Start_Date
# 2021-01-07  Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# 2021-01-12  Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# 2021-01-12  Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# 2021-01-12  Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# ...

# %%
df_PM_raw = pd.read_csv('../amz_reports/PMJI.csv')


df_PM_raw.sample(10)
# Out:
#        Start Date      End Date Portfolio name Currency  \
# 143  Nov 24, 2020  Nov 24, 2020    Not grouped      USD
# 22   Nov 20, 2020  Dec 10, 2020    Not grouped      USD
# 227  Nov 19, 2020  Nov 19, 2020    Not grouped      USD
# 263  Nov 21, 2020  Nov 21, 2020    Not grouped      USD
# 165  Dec 09, 2020  Dec 09, 2020    Not grouped      USD
# 196  Nov 22, 2020  Nov 22, 2020    Not grouped      USD
# 216  Nov 19, 2020  Nov 19, 2020    Not grouped      USD
# 180  Nov 25, 2020  Nov 25, 2020    Not grouped      USD
# 59   Dec 06, 2020  Dec 06, 2020    Not grouped      USD
# 217  Nov 24, 2020  Nov 28, 2020    Not grouped      USD
#
#                              Campaign Name   Ad Group Name  \
# 143  Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# 22   Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# 227  Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# 263  Advertise Catalog_ONB 10-23-2019 21ea  nosh - Kitchen
# ...
